# %%
# !pip install pyogrio==0.7.2 geopandas==0.14.3 unidecode -q
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# %load_ext autoreload
# %autoreload 2

import sys, os
from IPython.core.magic import register_cell_magic
import glob
import pickle
from unidecode import unidecode
import numpy as np
from google.colab import drive
import ee
import geemap
import scipy
import pandas as pd
import geopandas as gpd
import pyproj
import pyarrow
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ee.Authenticate()
ee.Initialize(project="215656163750")
drive.mount('/content/drive')

gpd.options.io_engine = "pyogrio"
os.environ["PYOGRIO_USE_ARROW"] = "1"

sys.path.append('/content/drive/MyDrive/Colab Notebooks/')
import utils

@register_cell_magic
def skip(line, cell):
    return

interim_path = "/content/drive/MyDrive/CAFO_data/forTraining/interim_files/"
shp_path = "/content/drive/MyDrive/CAFO_data/"
out_path = "/content/drive/MyDrive/CAFO_data/forTraining/"
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""
prefix = 'iowa'
bldgs_file = f"{interim_path}Iowa_bldgs_filtered.pkl"
boundary_shapefile = 'USA/cb_2021_us_county_5m.shp'
adm_no = '2'
"""

"""
prefix = 'chl'
bldgs_file = f"{interim_path}Chile_bldgs_filtered.pkl"
boundary_shapefile = 'Chile/shapefiles/chl_admbnda_adm3_bcn_20211008.shp'
adm_no = '3'
"""

#"""
prefix = 'mex'
bldgs_file = f"{interim_path}Mexico_bldgs_filtered.pkl"
boundary_shapefile = 'Mexico/shapefiles/mex_admbnda_adm2_govmex_20210618.shp'
adm_no = '2'
#"""

"""
prefix = 'rou'
bldgs_file = f"{interim_path}Romania_bldgs_filtered.pkl"
boundary_shapefile = f"Europe/shapefiles/geoBoundaries-ROU-ADM2_simplified.geojson"
adm_no = '2'
"""

print("")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
sentinel_bands = ['B4', 'B3', 'B2'] # mainly to reduce data volume/get max resolution
                                    # keep bands in this order

training_image_radius = 240 # m, to obtain (approx) 48 x ?? pixel images
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Get the df containing the farm and not-farm buildings/locations selected for
# training.

bldgs = pd.read_pickle(bldgs_file)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Get the ADMx-level boundaries for each country. This is just to break things
# up into chunks that don't make Earth Engine barf. Mexico has to be done at
# the ADM2 level, Iowa at ADM2, and Chile at ADM3. This creates a ridiculous
# number of files and should be recoded to use a grid or something instead.

def modify_shapefile(shpfile):
  shp = gpd.read_file(f"{shp_path}{shpfile}")

  # Get consistent CRSs
  try:
    shp = shp.set_crs("EPSG:4326")
  except ValueError:
    shp = shp.to_crs("EPSG:4326")

  # Get consistent column names

  # Iowa, assuming COUNTY-level
  try:
    shp.loc[:, "ADM2"] = shp["NAME"]
  except KeyError:
    pass

  # Romania
  try:
    shp.loc[:, "ADM2"] = shp["shapeName"]
  except KeyError:
    pass

  # Mexico, Chile
  shp.rename(columns={"ADM0_ES": "ADM0", "ADM1_ES": "ADM1",\
                      "ADM2_ES": "ADM2", "ADM3_ES": "ADM3"}, inplace=True)

  return shp
areas = modify_shapefile(boundary_shapefile)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Identify the administrative regions that contain farm/not-farm locations,
# because we don't want to bother iterating over ones with no farms

def narrow_down(bldgs_df, boundaries_df, adm_no):

  bldgs_df.loc[:, 'location_geom'] = bldgs_df.loc[:, 'geometry']
  joined = boundaries_df.sjoin(bldgs_df, how='inner', predicate='intersects')

  # create a df containing only boundaries containing buildings
  bounds_w_data = joined.drop_duplicates(subset=[f'ADM{adm_no}'])

  # create a version of the buildings df in which ADMx is identified
  bldgs_df_2 = joined.drop(columns=['geometry'])\
                     .rename(columns={'location_geom': 'geometry'})\
                     .set_geometry('geometry')

  # drop extraneous columns, but keep admin areas as they will be useful for
  # defining held-out regions later on
  columns_to_keep = bldgs_df.columns.to_list()
  additional = list(set([f'ADM{adm_no}', 'ADM2', 'ADM1', 'ADM0']))
  for column in additional:
    if column not in bldgs_df_2.columns:
      bldgs_df_2.loc[:, column] = np.nan
  columns_to_keep = columns_to_keep + additional
  columns_to_keep.remove('location_geom')
  bldgs_df_2 = bldgs_df_2[columns_to_keep]

  return bounds_w_data, bldgs_df_2

areas_2, bldgs_2 = narrow_down(bldgs, areas, adm_no=adm_no)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to obtain Sentinel data for a specified region

# Data for 2020, because the infrastructure dataset (next cell) appears to be from 2021
#   - May be better to use an earlier year in the hope of excluding unregistered CAFOs,
#     which might be post-2021?
#   - May be better to restrict to a certain season
#   - May need to use better cloud masking:
# https://developers.google.com/earth-engine/tutorials/community/sentinel-2-s2cloudless

def get_sentinel(boundary, sentinel_bands):

  sentinel = (
      ee.ImageCollection('COPERNICUS/S2_SR_HARMONIZED')
      .filterDate('2020-01-01', '2020-12-31')
      .filter(ee.Filter.lt('CLOUDY_PIXEL_PERCENTAGE', 10))
      .select(sentinel_bands)
      .median() #crude cloud filter
      .clip(boundary)
  )

  return sentinel
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Function to clip Sentinel data to an area around each farm and not-farm
# building

def extract_snippets(buildings_fc, sentinel_data, filename=None, folder=None):

  # For each polygon, define a square region around its centroid
  def buffer_and_bound(feature, buffer_radius=training_image_radius):
    return feature.centroid().buffer(buffer_radius, 2).bounds()

  areas = buildings_fc.map(buffer_and_bound)

  # Obtain Sentinel data for the polygon
  pix = sentinel_data.sampleRegions(
      collection=areas,
      scale=10,
      geometries=True)

  return areas, pix
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
#%%skip
# Get the Sentinel snippets for each location in each AMDx-level area, and write
# to file. This is where we create the ridiculous number of files.

# O'Brien county in Iowa fails, presumably b/c of data volume. This is tolerable
# because Iowa already has many more farms than the other datasets, but it
# underscores the need for a better way of doing this.

def create_interim_files(bldgs, bounds, prefix, adm_no, verbose=False):

  for place in bounds[f'ADM{adm_no}']:

    # Convert building info and boundary to ee featureCollections
    geometry = geemap.gdf_to_ee(bounds[bounds[f'ADM{adm_no}']==place][['geometry']])
    bldgs_fc = geemap.gdf_to_ee(bldgs[bldgs[f'ADM{adm_no}'] == place])

    # Get the Sentinel data for this area
    sentinel = get_sentinel(geometry, sentinel_bands)

    # Extract Sentinel data around each building location
    _, pix = extract_snippets(bldgs_fc, sentinel)

    # Save a file containing all the snippets for each region
    fname = unidecode(place).title().replace(" ", "").strip()
    try:
      utils.write_to_file(pix, f"{prefix}_{fname}", 'interim_files')
      if verbose:
        print(f"Saving {prefix}: {place} (-->{fname})")
    except:
      print(f" -- {place} failed")

create_interim_files(bldgs_2, areas_2, prefix, adm_no)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
utils.ee_task_status(n_tasks=10)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Task MAGDWIBH4AJSCSY2HFCKVGO7 started at 1970-01-01 00:00:00
# Current status: READY
# Task YNF4P7YSESOA3YS5C7VEXICE started at 1970-01-01 00:00:00
# Current status: READY
# Task 4PYVJ7SGLR6SI6U23XZJVGXH started at 1970-01-01 00:00:00
# Current status: READY
# Task 4CX3QYUVDUAJCOCHY6IBFLA6 started at 1970-01-01 00:00:00
# Current status: READY
# Task QG5PEUDEIUG2EYFXH4C2GMDS started at 1970-01-01 00:00:00
# Current status: READY
# Task VSXLPHRMYL2OFG5ODWEQACQX started at 1970-01-01 00:00:00
# Current status: READY
# Task J43RBETV2WRWKBUZUDEIEMX5 started at 1970-01-01 00:00:00
# Current status: READY
# Task XT2P5H76N23R6CHFFUKXGHZ6 started at 1970-01-01 00:00:00
# Current status: READY
# Task LBVFTBBMH25VTKZXC2RRL7DC started at 1970-01-01 00:00:00
# Current status: READY
# Task XGM5SUBUOKXKPSRDTLA7UARC started at 1970-01-01 00:00:00
# Current status: READY

# %%
print(f"There are {len(areas_2)} districts in {prefix}")
files = glob.glob(f'{interim_path}{prefix}*.geojson')
print(f"Have saved the Sentinel snippets for {len(files)} of them")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# There are 736 districts in mex
# Have saved the Sentinel snippets for 736 of them

# %%
# Convert pixel coords and values into a dictionary of 3D numpy array (height,
# width, channels). Band order is RGB, images are 64x64 pix, scaled to 0-255.
# This format should be suitable for keras preprocess_input functions, e.g.
# www.tensorflow.org/api_docs/python/tf/keras/applications/vgg16/preprocess_input

def create_images(gdf, index_start, verbose=False):

    # Remove suffixes from pixel ID numbers so we can group all pixels for a
    # given farm or not-farm
    # E.g, 1_1, 1_2, 1_3, 1_4 --> 1, 1, 1, 1

    gdf['id'] = gdf['id'].str.split('_').str[0]

    # Convert to int - this is very important, without it the gdf and image dict
    # end up out of sync!
    gdf['id'] = gdf['id'].astype(int)

    rejected = []
    arr_list = []

    # Here, a group will be an individual farm or not-farm
    groups = gdf.groupby(by='id')
    for n, group in groups:
      data = {'B4': [], 'B3': [], 'B2': []}
      # Identify image rows for each farm/not-farm
      _ = group.groupby(by=group.geometry.y)
      # Gather the group's pixels into a 3D array
      for coord, vals in _:
        for band in ['B4', 'B3', 'B2']:
          data[band].append([b for b in vals[band]])
      try:
        arr = np.stack([np.array(data['B4']), np.array(data['B3']), np.array(data['B2'])])
      except ValueError as e:
        # These are presumably groups that intersect with the boundary of the region
        # They cause problems because they aren't rectangular; might able to pad but
        # that seems like more trouble than it's worth
        rejected.append(group['id'].unique()[0])
        continue

      # Move the channels axis to the end
      arr = np.moveaxis(arr, [0], [2])

      # Resize the images to 64 x 64 pix
      arr = scipy.ndimage.zoom(
          arr,
          (64/arr.shape[0], 64/arr.shape[1], 1),
          mode='reflect'
          )

      # Rescale to 0-255 (using max over all bands)
      arr = (arr / np.max(arr)) * 255

      # The image is ready now, so add it to the dict
      arr_list.append(arr)

    # Create a version of the input array that has just one row per farm/not-farm
    # and doesn't include the now-redundant band info
    gdf = gdf[~gdf['id'].isin(rejected)]
    gdf = gdf.drop(columns=['B2', 'B3', 'B4']).drop_duplicates(subset=['id'])\
             .drop(columns=['id'])
    new_index = [i for i in range(index_start, index_start+len(gdf))]
    gdf.index = new_index

    # Make a dict of arrays in which keys are guaranteed to match gdf
    arr_dict = {key: value for key, value in zip(new_index, arr_list)}

    if verbose:
      print(f"Started with {len(groups)} farms/not-farms")
      print(f"Rejected {len(rejected)} images with irregular shapes")
      print(f'Retained {len(new_index)} images')

    return arr_dict, gdf
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# %%time

def images_and_metadata(prefix, verbose=False):
  files = glob.glob(f'{interim_path}{prefix}*.geojson')

  gdf_list = []
  index_start = 0
  image_dict_list = []

  for n, f in enumerate(files):
    if verbose:
      print(f"Working on #{n}: {f}")
    gdf = gpd.read_file(f)
    image_dict, gdf = create_images(gdf, index_start)
    if len(gdf) == 0:
      # No images remain after rejecting irregular ones
      continue
    gdf_list.append(gdf)
    image_dict_list.append(image_dict)
    index_start += len(gdf)

  main_gdf = pd.concat(gdf_list)
  image_dict = image_dict_list[0]
  for d in image_dict_list[1:]:
    image_dict.update(d)

  main_gdf.to_pickle(f"{out_path}{prefix}_metadata_gdf.pkl")
  with open(f"{out_path}{prefix}_sentinel_images.pkl", 'wb') as f:
    pickle.dump(image_dict, f, protocol=pickle.HIGHEST_PROTOCOL)

  return main_gdf, image_dict

df, image_dict = images_and_metadata(prefix, verbose=True)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Working on #0: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Abala.geojson
# Working on #1: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AcatlanDeJuarez.geojson
# Working on #2: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acambaro.geojson
# Working on #3: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AcambayDeRuizCastaneda.geojson
# Working on #4: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acaponeta.geojson
# Working on #5: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acala.geojson
# Working on #6: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acolman.geojson
# Working on #7: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AcapulcoDeJuarez.geojson
# Working on #8: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acatlan.geojson
# Working on #9: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acayucan.geojson
# Working on #10: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Abasolo.geojson
# Working on #11: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acaxochitlan.geojson
# Working on #12: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acanceh.geojson
# Working on #13: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acuna.geojson
# Working on #14: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AguaBlancaDeIturbide.geojson
# Working on #15: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Actopan.geojson
# Working on #16: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Aculco.geojson
# Working on #17: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Aconchi.geojson
# Working on #18: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acuitzio.geojson
# Working on #19: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ahumada.geojson
# Working on #20: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ahuacuotzingo.geojson
# Working on #21: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ahuacatlan.geojson
# Working on #22: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AguaDulce.geojson
# Working on #23: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Aldama.geojson
# Working on #24: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AlamoTemapache.geojson
# Working on #25: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Alfajayucan.geojson
# Working on #26: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AhualulcoDeMercado.geojson
# Working on #27: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ajalpan.geojson
# Working on #28: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acultzingo.geojson
# Working on #29: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Alvarado.geojson
# Working on #30: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Altotonga.geojson
# Working on #31: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Altar.geojson
# Working on #32: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ahome.geojson
# Working on #33: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Allende.geojson
# Working on #34: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Acatic.geojson
# Working on #35: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AlmoloyaDeJuarez.geojson
# Working on #36: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Alamos.geojson
# Working on #37: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AlvaroObregon.geojson
# Working on #38: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Amacueca.geojson
# Working on #39: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Amecameca.geojson
# Working on #40: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Amatitan.geojson
# Working on #41: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AmatlanDeCanas.geojson
# Working on #42: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Aguascalientes.geojson
# Working on #43: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Altamira.geojson
# Working on #44: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Altepexi.geojson
# Working on #45: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Angamacutiro.geojson
# Working on #46: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Angostura.geojson
# Working on #47: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AmatlanDeLosReyes.geojson
# Working on #48: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Amozoc.geojson
# Working on #49: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Arizpe.geojson
# Working on #50: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_ApaseoElGrande.geojson
# Working on #51: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Apaxco.geojson
# Working on #52: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Apatzingan.geojson
# Working on #53: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AmealcoDeBonfil.geojson
# Working on #54: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Apan.geojson
# Working on #55: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_ApaseoElAlto.geojson
# Working on #56: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ascension.geojson
# Working on #57: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AtemajacDeBrizuela.geojson
# Working on #58: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Arteaga.geojson
# Working on #59: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ameca.geojson
# Working on #60: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Apulco.geojson
# Working on #61: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ario.geojson
# Working on #62: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atzacan.geojson
# Working on #63: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Asientos.geojson
# Working on #64: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AtotonilcoElGrande.geojson
# Working on #65: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atoyatempan.geojson
# Working on #66: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atlixco.geojson
# Working on #67: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atoyac.geojson
# Working on #68: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Arandas.geojson
# Working on #69: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atlacomulco.geojson
# Working on #70: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atlatlahucan.geojson
# Working on #71: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atltzayanca.geojson
# Working on #72: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atitalaquia.geojson
# Working on #73: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Apodaca.geojson
# Working on #74: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Arriaga.geojson
# Working on #75: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atenguillo.geojson
# Working on #76: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atengo.geojson
# Working on #77: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Atenco.geojson
# Working on #78: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Baca.geojson
# Working on #79: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AutlanDeNavarro.geojson
# Working on #80: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Badiraguato.geojson
# Working on #81: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Axapusco.geojson
# Working on #82: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ayapango.geojson
# Working on #83: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Bacum.geojson
# Working on #84: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Berriozabal.geojson
# Working on #85: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Brisenas.geojson
# Working on #86: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Burgos.geojson
# Working on #87: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ayotlan.geojson
# Working on #88: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_AtotonilcoElAlto.geojson
# Working on #89: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Baviacora.geojson
# Working on #90: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Ayala.geojson
# Working on #91: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Balancan.geojson
# Working on #92: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Banamichi.geojson
# Working on #93: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Caborca.geojson
# Working on #94: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Buenaventura.geojson
# Working on #95: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Bustamante.geojson
# Working on #96: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_BenitoJuarez.geojson
# Working on #97: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Cacalchen.geojson
# Working on #98: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_BuenavistaDeCuellar.geojson
# Working on #99: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Cacahoatan.geojson
# Working on #100: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_PasoDelMacho.geojson
# Working on #101: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CamaronDeTejeda.geojson
# Working on #102: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Calera.geojson
# Working on #103: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Camargo.geojson
# Working on #104: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Calkini.geojson
# Working on #105: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Calimaya.geojson
# Working on #106: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Champoton.geojson
# Working on #107: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CerroDeSanPedro.geojson
# Working on #108: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Cerralvo.geojson
# Working on #109: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Cardenas.geojson
# Working on #110: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Centla.geojson
# Working on #111: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Carmen.geojson
# Working on #112: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Cedral.geojson
# Working on #113: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CarrilloPuerto.geojson
# Working on #114: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CanadaMorelos.geojson
# Working on #115: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Campeche.geojson
# Working on #116: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Cantamayec.geojson
# Working on #117: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CadereytaDeMontes.geojson
# Working on #118: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Canatlan.geojson
# Working on #119: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Candelaria.geojson
# Working on #120: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CanadasDeObregon.geojson
# Working on #121: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_CadereytaJimenez.geojson
# Working on #122: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Chilchota.geojson
# Working on #123: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_ChiapaDeCorzo.geojson
# Working on #124: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Chiautla.geojson
# Working on #125: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Chicoloapan.geojson
# Working on #126: /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_Chiautempan.geojson

# %%
# Tidy up - run this cell and then empty trash in drive. While it takes a long
# time to create the geojson files of Sentinel snippets, they do take up a lot
# of space. And if I need to rerun this notebook, it's probably because I've
# changed the farm and not-farm locations anyway.

if prefix == 'iowa':
  # !rm /content/drive/MyDrive/CAFO_data/forTraining/interim_files/iowa_*.geojson
elif prefix == 'mex':
  # !rm  /content/drive/MyDrive/CAFO_data/forTraining/interim_files/mex_*.geojson
elif prefix == 'chl':
  # !rm /content/drive/MyDrive/CAFO_data/forTraining/interim_files/chl_*.geojson
elif prefix == 'rou':
  # !rm /content/drive/MyDrive/CAFO_data/forTraining/interim_files/rou_*.geojson
else:
  print("Don't know what to delete, not doing anything")
