# %%
try:
  import livelossplot
except ModuleNotFoundError:
  # !pip install livelossplot -q

# %%
# %load_ext autoreload
# %autoreload 2

import sys
import os
import pickle
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from google.colab import drive
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import VGG16
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.applications import ResNet50
from keras.applications.vgg16 import preprocess_input as preprocess_input_vgg16
from keras.applications.efficientnet import preprocess_input as preprocess_input_efficientnet
from keras.applications.resnet50 import preprocess_input as preprocess_input_resnet
from keras.models import load_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Input, Dropout, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from livelossplot.inputs.keras import PlotLossesCallback

# %%
drive.mount('/content/drive')
sys.path.append('/content/drive/MyDrive/Colab Notebooks/')
import utils
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
use_model = VGG16
model_name = "VGG16"
preprocessing = preprocess_input_vgg16

#use_model = EfficientNetB0
#model_name = "EfficientNetB0"
#preprocessing = preprocess_input_efficientnet

#use_model = ResNet50
#model_name = "ResNet50"
#preprocessing = preprocess_input_resnet

# %%
datasets = ["chl_iter0", "rou_iter0", "iowa_iter0", "mex_iter1"]
data_name = "data_combo_1"

# %%
data_path = "/content/drive/MyDrive/CAFO_data/forTraining/"

gdf_list = []
for dataset in datasets:

  gdf = pd.read_pickle(f'{data_path}{dataset}.pkl')
  print(f"There are {len(gdf)} rows in the {dataset} dataset")
  birds = gdf[gdf["Farm type"].isin(["Poultry", "Layer", "Broiler"])]
  pigs = gdf[gdf["Farm type"] == "Pig"]
  unk = gdf[gdf["Farm type"] == "Unknown CAFO"]
  non_farms = gdf[gdf["Farm type"].isin(["Non-farm", "Feedlot", "Dairy"])]
  print(f" -- {len(birds)} poultry farms")
  print(f" -- {len(pigs)} pig farms")
  print(f" -- {len(unk)} unknown CAFOs")
  print(f" -- {len(non_farms)} other buildings")

  # Sample from Iowa pig farms and not-farms
  # Same rows each time
  if "iowa" in dataset:
    gdf1 = gdf[gdf["Farm type"].isin(["Poultry", "Layer", "Broiler",])]
    print(f"  --> Keeping all {len(gdf1)} Iowa poultry farms")
    gdf2 = gdf[gdf["Farm type"] == "Pig"].sample(200, random_state=42)
    print(f"  --> Sampling {len(gdf2)} Iowa pig farms")
    gdf3 = gdf[gdf["Farm type"] == "Non-farm"].sample(500, random_state=42)
    print(f"  --> Sampling {len(gdf3)} Iowa not-farms")
    gdf = pd.concat([gdf1, gdf2, gdf3])

  gdf_list.append(gdf)

data = pd.concat(gdf_list).reset_index(drop=True)
print(f"There is a total of {len(data)} rows")
# Out:
# There are 664 rows in the chl_iter0 dataset
#  -- 179 poultry farms
#  -- 131 pig farms
#  -- 0 unknown CAFOs
#  -- 354 other buildings
# There are 809 rows in the rou_iter0 dataset
#  -- 253 poultry farms
#  -- 120 pig farms
#  -- 0 unknown CAFOs
#  -- 436 other buildings
# There are 5886 rows in the iowa_iter0 dataset
#  -- 65 poultry farms
#  -- 2752 pig farms
#  -- 0 unknown CAFOs
#  -- 3069 other buildings
#   --> Keeping all 65 Iowa poultry farms
#   --> Sampling 200 Iowa pig farms
#   --> Sampling 500 Iowa not-farms
# There are 8004 rows in the mex_iter1 dataset
#  -- 1983 poultry farms
#  -- 893 pig farms
#  -- 239 unknown CAFOs
#  -- 4889 other buildings
# There is a total of 10242 rows
# /usr/local/lib/python3.10/dist-packages/geopandas/array.py:1638: UserWarning: CRS not set for some of the concatenation inputs. Setting output's CRS as WGS 84 (the single non-null crs provided).
#   return GeometryArray(data, crs=_get_common_crs(to_concat))

# %%
images = []
labels = []
metadata_list = []

for idx, row in data.iterrows():
  # Glom all farm types into a single "CAFO" class
  if row['Farm type'] in ["Poultry", "Broiler", "Layer", "Pig", "Unknown CAFO"]:
    labels.append("CAFO")
    images.append(row["Sentinel"])
  elif row['Farm type'] in ["Non-farm", "Feedlot", "Dairy"]:
    labels.append("Not-CAFO")
    images.append(row["Sentinel"])
  else:
    print(f"Unexpected farm type, {row['Farm type']}")
  metadata_list.append(row.drop(["Sentinel"]).to_dict())

# Labels --> categorical --> one hot
label_encoder = LabelEncoder()
encoded_labels = label_encoder.fit_transform(labels)
one_hot_labels = to_categorical(encoded_labels, num_classes=len(set(labels)))

class_mapping = dict(zip(encoded_labels, labels))
print("Class mapping:", class_mapping)
n_classes = len(class_mapping)

# Recombine images, labels, and metadata into a DataFrame for shuffling
data1 = list(zip(images, one_hot_labels, metadata_list))
df = pd.DataFrame(data1, columns=['image', 'label', 'metadata'])

# Shuffle the data
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
# Out:
# Class mapping: {1: 'Not-CAFO', 0: 'CAFO'}

# %%
# Create training, validation, and test datasets

# Split into (training+validation) and test sets (10% for testing)
train_val_df, test_df = train_test_split(df, test_size=0.1, random_state=42)

# Split training + validation into training and validation sets (~20% for val)
train_df, val_df = train_test_split(train_val_df, test_size=0.22,\
                                    random_state=42)

# Extract the split data
X_train = np.array(train_df['image'].tolist())
y_train = np.array(train_df['label'].tolist())

X_val = np.array(val_df['image'].tolist())
y_val = np.array(val_df['label'].tolist())

X_test = np.array(test_df['image'].tolist())
y_test = np.array(test_df['label'].tolist())

# The index of each item in X_train etc. should correspond to the index in
# the appropriate dataframe
metadata_train = pd.json_normalize(train_df['metadata'])
metadata_val = pd.json_normalize(val_df['metadata'])
metadata_test = pd.json_normalize(test_df['metadata'])

# Print the number of training, validation, and test images
print(f"Training set: {X_train.shape[0]} images")
print(f"Validation set: {X_val.shape[0]} images")
print(f"Test set: {X_test.shape[0]} images")

# Keep copies of original data as the arrays can get changed by the data
# generators (this should be handled differently?)
X_train_original = np.copy(X_train)
X_val_original = np.copy(X_val)
X_test_original = np.copy(X_test)
# Out:
# Training set: 7189 images
# Validation set: 2028 images
# Test set: 1025 images

# %%
# Set up data generators, augmenting training data but not validation + test data

train_datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True,
    preprocessing_function=preprocessing
    )

val_datagen = ImageDataGenerator(
    preprocessing_function=preprocessing
    )

# %%
# Create the model so as to fine-tune only the top 2 (non-convolutional) layers
# This is essentially extracting existing features and re-learning how to
# classify based on them

learning_rate = 0.001

input_shape=X_train.shape[1:]
optimizer=Adam(learning_rate=learning_rate)
weights_file = f'/content/drive/MyDrive/CAFO_models/{model_name}_{data_name}/model.keras'

# Load pretrained layers, excluding fully-connected layers
base_model = use_model(include_top=False,
                  weights='imagenet',
                  input_shape=input_shape)

# Freeze pretrained layers
base_model.trainable = False
top_model = base_model.output

if use_model == VGG16:
  # Create new fully-connected layers for classification
  top_model = Flatten(name="flatten")(top_model)
  top_model = Dense(512, activation='relu')(top_model)
  top_model = Dropout(0.5)(top_model)
  top_model = Dense(256, activation='relu')(top_model)
  top_model = Dropout(0.5)(top_model)
  output_layer = Dense(n_classes, activation='softmax')(top_model)

elif use_model in [EfficientNetB0, ResNet50]:
  top_model = GlobalAveragePooling2D()(top_model)
  output_layer = Dense(n_classes, activation='softmax')(top_model)

else:
  raise ValueError(f"Unknown model {use_model}")

# Combine the base (convolutional) and top (fully-connected) layers
model = Model(inputs=base_model.input, outputs=output_layer)

# If we have already done this step, can load saved weights from file
if weights_file is not None:
  print(f'Loading model from {weights_file}')
  model.load_weights(weights_file)

# Compile the model for training.
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# Loading model from /content/drive/MyDrive/CAFO_models/VGG16_data_combo_1/model.keras

# %%
# Define early stopping + other callbacks.

lr = ReduceLROnPlateau(
                      factor=0.5,
                      monitor='val_loss',
                      min_delta=0,
                      patience=3,
                      min_lr=1e-6,
                      verbose=1
                      )

es = EarlyStopping(
                  monitor='val_loss',
                  mode='min',
                  restore_best_weights=True,
                  min_delta=0.01, #increased from 0
                  patience=4, #reduced from 6
                  verbose=1
                  )

mc = ModelCheckpoint(
                    f'/content/drive/MyDrive/CAFO_models/{model_name}_{data_name}/model.keras',
                    monitor='val_loss',
                    mode='min',
                    verbose=1,
                    save_best_only=True
                    )

pl = PlotLossesCallback()

# %%
# Fit the model, if we haven't reloaded a previously-fitted one

if weights_file is None:

  history = model.fit(
                    train_datagen.flow(X_train, y_train, batch_size=32),
                    validation_data=val_datagen.flow(X_val, y_val, batch_size=32),
                    epochs=50,
                    callbacks=[lr, es, mc, pl],
                    verbose=2
                    )

# %%
# Use the model to make predictions for the test data. As
# EarlyStopping.restore_best_weights=True, this should be the best model,
# not just the final epoch's one

results = utils.get_predictions(model, X_test, y_test, model_name, metadata_test)

# Generate sklearn classification report
print('\n', classification_report(results["Label"].to_list(),\
                                  results['Model Class'].to_list()))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step
#
#                precision    recall  f1-score   support
#
#            0       0.85      0.72      0.78       395
#            1       0.84      0.92      0.88       630
#
#     accuracy                           0.84      1025
#    macro avg       0.85      0.82      0.83      1025
# weighted avg       0.84      0.84      0.84      1025

# %%
# Show some of the correctly- and incorrectly-classified images. Use the
# "ascending" kw to say whether the images should be arranged in order
# of ascending probability (True/False)

utils.plot_classified_images(X_test, results, class_mapping, ascending=False)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
utils.probability_hist(results, ymax=200, fname="hist_train")

# %%
# Fine-tune the model

# Set a block or some layers to be trainable
for layer in base_model.layers:
    if use_model == VGG16 and 'block4' in layer.name:
        layer.trainable = True
        print(f"Layer {layer.name} is trainable")
    elif use_model == EfficientNetB0 and 'block7a' in layer.name:
        layer.trainable = True
        print(f"Layer {layer.name} is trainable")
    elif use_model == ResNet50 and "conv5" in layer.name:
        layer.trainable = True
        print(f"Layer {layer.name} is trainable")

# Compile the model with a lower learning rate
# Model compiling does not change weights; see
# stackoverflow.com/questions/47995324/does-model-compile-initialize-all-the-
# weights-and-biases-in-keras-tensorflow
optimizer=Adam(learning_rate=learning_rate*0.2)
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Update parameters for Reduce LR and EarlyStopping to reduce overfitting
lr = ReduceLROnPlateau(
                      factor=0.5,
                      monitor='val_loss',
                      min_delta=0.03,
                      patience=3,
                      min_lr=1e-6,
                      verbose=2
                      )

es = EarlyStopping(
                  monitor='val_loss',
                  mode='min',
                  restore_best_weights=True,
                  min_delta=0.02, #reduced from 0.03
                  patience=4, #reduced from 6
                  verbose=2
                  )

# Specify a new filename for best model
mc = ModelCheckpoint(
                    f'/content/drive/MyDrive/CAFO_models/{model_name}_{data_name}/model_ft.keras',
                    monitor='val_loss',
                    mode='min',
                    verbose=2,
                    save_best_only=True
                    )

# Reset the plots
pl = PlotLossesCallback()
# Out:
# Layer block4_conv1 is trainable
# Layer block4_conv2 is trainable
# Layer block4_conv3 is trainable
# Layer block4_pool is trainable

# %%
weights_file = f'/content/drive/MyDrive/CAFO_models/{model_name}_{data_name}/model_ft.keras'

if weights_file is not None:
  # Skip fine-tuning and proceed to examine results from existing fine-tuned
  # model
  print(f'Loading weights from {weights_file}')
  model.load_weights(weights_file) #load weights or whole model?

else:

  # Uncomment if this fine-tuning step is interrupted and restarted
  # Otherwise I'm not sure where fitting will start from
  #weights_file = f'/content/drive/MyDrive/CAFO_models/{model_name}_{data_name}/model.keras'
  #model.load_weights(weights_file)

  # Fit the model
  ft_history = model.fit(
                    train_datagen.flow(X_train, y_train, batch_size=32),
                    validation_data=val_datagen.flow(X_val, y_val, batch_size=32),
                    epochs=50,
                    callbacks=[lr, mc, es, pl],
                    verbose=2
                    )
# Out:
# Loading weights from /content/drive/MyDrive/CAFO_models/VGG16_data_combo_1/model_ft.keras
# /usr/local/lib/python3.10/dist-packages/keras/src/saving/saving_lib.py:713: UserWarning: Skipping variable loading for optimizer 'adam', because it has 2 variables whereas the saved optimizer has 26 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %%
results_ft = utils.get_predictions(model, X_test, y_test, model_name, metadata_test)

print('\n', classification_report(results_ft["Label"].to_list(),\
                                  results_ft['Model Class'].to_list()))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
#
#                precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90       395
#            1       0.93      0.95      0.94       630
#
#     accuracy                           0.92      1025
#    macro avg       0.92      0.92      0.92      1025
# weighted avg       0.92      0.92      0.92      1025

# %%
utils.plot_classified_images(X_test, results_ft, class_mapping, ascending=False)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
utils.probability_hist(results_ft, ymax=350, fname="hist_train_ft")

# %%
# Define the last convolutional layer based on the model type
last_conv_layer_name = 'block4_conv3' if use_model == VGG16 else 'top_conv'

# Get a test image
prediction = 1
label = 0
probability_range = (0.5, 0.7)
image, preprocessed_image = utils.select_test_image(X_test, model_name,\
                                                    results_ft, prediction,\
                                                    label, probability_range)

# Create and display its Grad-CAM heatmap
heatmap = utils.get_gradcam_heatmap(model, preprocessed_image,\
                                    last_conv_layer_name, prediction)
utils.display_gradcam(image, heatmap, alpha=0.5)
# Out:
# Dataset: Mexico
# Probability = 0.50

# %%
# A second VGG16 fine-tuning step, for block 5 this time, starting with the
# new layer 4 features and the weights from the last step

# Set a block or some layers to be trainable
for layer in base_model.layers:
    if 'block5' in layer.name:
        layer.trainable = True
        print(f"Layer {layer.name} is now trainable")
    if 'block4' in layer.name:
        layer.trainable = False
        print(f"Layer {layer.name} is no longer trainable")


# Compile the model with a lower learning rate
optimizer=Adam(learning_rate=learning_rate*0.05) # reduced from *0.2 in previous step
model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

lr = ReduceLROnPlateau(
                      factor=0.5,
                      monitor='val_loss',
                      min_delta=0.03,
                      patience=3,
                      min_lr=1e-6,
                      verbose=1
                      )

es = EarlyStopping(
                  monitor='val_loss',
                  mode='min',
                  restore_best_weights=True,
                  min_delta=0.01, #reduced from 0.02 in previous step
                  patience=3, #reduced from 4 in previous step
                  verbose=1
                  )

mc = ModelCheckpoint(
                    f'/content/drive/MyDrive/CAFO_models/{model_name}_{data_name}/model_ft2.keras',
                    monitor='val_loss',
                    mode='min',
                    verbose=1,
                    save_best_only=True
                    )

pl = PlotLossesCallback()

ft2_history = model.fit(
                    train_datagen.flow(X_train, y_train, batch_size=32),
                    validation_data=val_datagen.flow(X_val, y_val, batch_size=32),
                    epochs=50,
                    callbacks=[lr, mc, es, pl],
                    verbose=2
                    )
# Out:
# accuracy
# 	training         	 (min:    0.919, max:    0.923, cur:    0.919)
# 	validation       	 (min:    0.907, max:    0.922, cur:    0.920)
# learning_rate
# 	learning_rate    	 (min:    0.000, max:    0.000, cur:    0.000)
# Loss
# 	training         	 (min:    0.205, max:    0.222, cur:    0.210)
# 	validation       	 (min:    0.176, max:    0.214, cur:    0.191)
# 225/225 - 21s - 91ms/step - accuracy: 0.9192 - loss: 0.2102 - val_accuracy: 0.9201 - val_loss: 0.1909 - learning_rate: 5.0000e-05
# Epoch 6: early stopping
# Restoring model weights from the end of the best epoch: 3.

# %%
results_ft2 = utils.get_predictions(model, X_test, y_test, model_name, metadata_test)

print('\n', classification_report(results_ft2["Label"].to_list(),\
                                  results_ft2['Model Class'].to_list()))
# Out:
# 33/33 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
#                precision    recall  f1-score   support
#
#            0       0.92      0.88      0.90       395
#            1       0.93      0.95      0.94       630
#
#     accuracy                           0.92      1025
#    macro avg       0.92      0.92      0.92      1025
# weighted avg       0.92      0.92      0.92      1025
